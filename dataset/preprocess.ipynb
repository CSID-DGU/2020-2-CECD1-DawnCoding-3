# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_excel("data2.xlsx")
df.head(10)
# Out:
#     No 명칭(Description)            Unnamed: 2  구성조건   구분 GoCB  RCB SCADA\nSEND  \
# 0  NaN             NaN                   NaN   NaN  NaN  NaN  NaN         NaN
# 1    1   (154kV 모선 보호)  87_A IED Live Status  LPHD   감시  NaN    ●           ●
# 2    2   (154kV 모선 보호)  87_B IED Live Status  LPHD   감시  NaN    ●           ●
# 3    3   (154kV 모선 보호)  87_C IED Live Status  LPHD   감시  NaN    ●           ●
# 4    4   (154kV 모선 보호)  27_1 IED Live Status  LPHD   감시  NaN    ●           ●
# 5    5   (154kV 모선 보호)  27_2 IED Live Status  LPHD   감시  NaN    ●           ●
# 6    6   (154kV 모선 보호)      87_A #1 통신 카드 상태  GGIO   감시  NaN    ●           ●
# 7    7   (154kV 모선 보호)      87_A #2 통신 카드 상태  GGIO   감시  NaN    ●           ●
# 8    8   (154kV 모선 보호)      87_B #1 통신 카드 상태  GGIO   감시  NaN    ●           ●
# 9    9   (154kV 모선 보호)      87_B #2 통신 카드 상태  GGIO   감시  NaN    ●           ●
#
#                 PD                                       Signal Name  ...  \
# ...

# %%
df.shape
# Out:
# (3032, 28)

# %%
new_df = df[['명칭(Description)', 'Signal Name', '상태표시']]
new_df.head()
# Out:
#   명칭(Description)                                       Signal Name 상태표시
# 0             NaN                                               NaN  NaN
# 1   (154kV 모선 보호)  E415_P6065_87_ACFG/DevIDLPHD1$ST$PhyHealth$stVal  NaN
# 2   (154kV 모선 보호)  E415_P6065_87_BCFG/DevIDLPHD1$ST$PhyHealth$stVal  NaN
# 3   (154kV 모선 보호)  E415_P6065_87_CCFG/DevIDLPHD1$ST$PhyHealth$stVal  NaN
# 4   (154kV 모선 보호)  E415_P6065_27_1CFG/DevIDLPHD1$ST$PhyHealth$stVal  NaN

# %%
new_df['상태표시'].value_counts()
# Out:
# 0 : 복귀  1 : 동작                                  264
# 0 : 복귀,     1 : 동작                              222
# 0 : 복귀 1 : 동작                                   201
# 0 : 복귀, 1 : 동작                                  100
# 0 : 동작 1 : 복귀                                    93
# 0 : 비정상\n1 : 정상                                  90
# 0 : 복귀,        1 : 동작                            78
# 0 : 잠김  1 : 해제                                   60
# 0 : 잠김,     1 : 해제                               56
# 0 : 동작중 1 : 열림 2 : 닫힘 3 : 비정상                    35
# 0 : 동작중  1 : 열림  2 : 닫힘  3 : 비정상                 34
# false : 정지,        true : 운전                     34
# 0 : 동작중,     1 : 열림,     2 : 닫힘,     3 : 비정상     28
# 0 : 비정상  1 : 정상                                  28
#   1 : ON  3 : TEST  5: OFF                       26
# 0 : 정지  1 : 운전                                   24
# 0 : 비정상 1 : 정상                                   24
# 0 : 비정상,     1 : 정상                              22
# ...
